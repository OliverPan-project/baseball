# %%
import pandas as pd
import numpy as np

# %%
source = "/Users/Oliver/Desktop/2016-mlb-season/baseball_reference_2016_clean.csv"
df = pd.read_csv(source)
pd.options.display.max_rows = 81
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-a1f8fe84baca> in <module>
#       1 source = "/Users/Oliver/Desktop/2016-mlb-season/baseball_reference_2016_clean.csv"
# ----> 2 df = pd.read_csv(source)
#       3 pd.options.display.max_rows = 81
#
# ...

# %%
df
# Out:
#       Unnamed: 0  attendance              away_team  away_team_errors  \
# 0              0     40030.0          New York Mets                 1
# 1              1     21621.0  Philadelphia Phillies                 0
# 2              2     12622.0        Minnesota Twins                 0
# 3              3     18531.0   Washington Nationals                 0
# 4              4     18572.0       Colorado Rockies                 1
# ...          ...         ...                    ...               ...
# 2458        2458     31042.0      Toronto Blue Jays                 2
# 2459        2459     39500.0    St. Louis Cardinals                 0
# 2460        2460     20098.0   San Francisco Giants                 0
# 2461        2461     17883.0         Detroit Tigers                 0
# 2462        2462     10298.0         Boston Red Sox                 1
#
#       away_team_hits  away_team_runs        date field_type   game_type  \
# ...

# %%
home = df[df['home_team'] == "Toronto Blue Jays" ]

# %%
home.set_index("date", inplace = True)
home.sort_index(inplace = True)

df['date'] = pd.to_datetime(df["date"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
home
# Out:
#             Unnamed: 0  attendance          away_team  away_team_errors  \
# date
# 2016-04-08        2416     48871.0     Boston Red Sox                 0
# 2016-04-09        2403     47138.0     Boston Red Sox                 1
# 2016-04-10        2391     46158.0     Boston Red Sox                 1
# 2016-04-12        2376     28819.0   New York Yankees                 1
# 2016-04-13          25     27938.0   New York Yankees                 1
# ...                ...         ...                ...               ...
# 2016-10-04         384     49934.0  Baltimore Orioles                 0
# 2016-10-09         375     49555.0      Texas Rangers                 1
# 2016-10-17         363     49507.0  Cleveland Indians                 0
# 2016-10-18         361     49142.0  Cleveland Indians                 1
# 2016-10-19         359     48800.0  Cleveland Indians                 0
#
#             away_team_hits  away_team_runs field_type   game_type  \
# date
# ...

# %%
home["attendance"].plot(figsize = (15,10))

# %%
home["attendance"].describe()
# Out:
# count       86.000000
# mean     42314.383721
# std       7331.237196
# min      23726.000000
# 25%      39626.750000
# 50%      46135.000000
# 75%      47304.000000
# max      49934.000000
# Name: attendance, dtype: float64

# %%
home[home["attendance"] == 49934]
# Out:
#             Unnamed: 0  attendance          away_team  away_team_errors  \
# date
# 2016-10-04         384     49934.0  Baltimore Orioles                 0
#
#             away_team_hits  away_team_runs field_type   game_type  \
# date
# 2016-10-04               4               2    on turf  Night Game
#
#                     home_team  home_team_errors  ...  temperature  wind_speed  \
# date                                             ...
# 2016-10-04  Toronto Blue Jays                 0  ...         63.0        18.0
#
#                  wind_direction    sky total_runs  game_hours_dec  \
# date
# 2016-10-04   from Right to Left  Night          7        3.416667
#
#                  season home_team_win home_team_loss  home_team_outcome
# date
# 2016-10-04  post season             1              0                Win
#
# [1 rows x 25 columns]

# %%
^^We won this game
